# %%
import pandas as pd 
df=pd.read_csv("/home/ad.rapidops.com/sakshi.sharma/Desktop/PYTHON/ML-learning/task/movies.csv")
for _, row in df.iterrows():
    print(row)
# Out:
# name                                            The Time Machine
# description    A man travels through time and witnesses the e...
# year                                                        1895
# director                                              H.G. Wells
# Name: 0, dtype: object
# name                                                Ender's Game
# description    A young boy is trained to become a military le...
# year                                                        1985
# director                                        Orson Scott Card
# Name: 1, dtype: object
# name                                             Brave New World
# description    A dystopian society where people are genetical...
# year                                                        1932
# director                                           Aldous Huxley
# Name: 2, dtype: object
# name                        The Hitchhiker's Guide to the Galaxy
# ...

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 35.4 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
__file__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 __file__
#
# NameError: name '__file__' is not defined
