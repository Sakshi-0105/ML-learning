# %%
pip install polars
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 12.0 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl
df = pl.read_csv(
    "test.csv",
    null_values=["NA"]   # replace "NA" with null
)
print(df.shape)
df.describe()
# Out:
# (1459, 80)
# shape: (9, 81)
# ┌────────────┬────────────┬───────────┬──────────┬───┬──────────┬───────────┬──────────┬───────────┐
# │ statistic  ┆ Id         ┆ MSSubClas ┆ MSZoning ┆ … ┆ MoSold   ┆ YrSold    ┆ SaleType ┆ SaleCondi │
# │ ---        ┆ ---        ┆ s         ┆ ---      ┆   ┆ ---      ┆ ---       ┆ ---      ┆ tion      │
# │ str        ┆ f64        ┆ ---       ┆ str      ┆   ┆ f64      ┆ f64       ┆ str      ┆ ---       │
# │            ┆            ┆ f64       ┆          ┆   ┆          ┆           ┆          ┆ str       │
# ╞════════════╪════════════╪═══════════╪══════════╪═══╪══════════╪═══════════╪══════════╪═══════════╡
# │ count      ┆ 1459.0     ┆ 1459.0    ┆ 1455     ┆ … ┆ 1459.0   ┆ 1459.0    ┆ 1458     ┆ 1459      │
# │ null_count ┆ 0.0        ┆ 0.0       ┆ 4        ┆ … ┆ 0.0      ┆ 0.0       ┆ 1        ┆ 0         │
# │ mean       ┆ 2190.0     ┆ 57.378341 ┆ null     ┆ … ┆ 6.104181 ┆ 2007.7697 ┆ null     ┆ null      │
# ...

# %%
a={}
b=a.copy()
b["name"]="sakshi"
print(a,b)
# Out:
# {} {'name': 'sakshi'}
